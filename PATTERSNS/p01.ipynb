# %%
n = 10

for i in range(0, n):
    if i == 0 or i == n - 1:
        print("* " * n)
    else:    
        
      print("* " + "  " * (n - 2) + "*")
# Out:
# * * * * * * * * * *
# *                 *
# *                 *
# *                 *
# *                 *
# *                 *
# *                 *
# *                 *
# *                 *
# * * * * * * * * * *

# %%
n = 10
for i in range(0, n):
    print("*" * (i + 1))
# Out:
# *
# **
# ***
# ****
# *****
# ******
# *******
# ********
# *********
# **********

# %%
n = 10
for i in range(n):
    print("*" * (n - i))
# Out:
# **********
# *********
# ********
# *******
# ******
# *****
# ****
# ***
# **
# *

# %%
n = 10
for i in range(n):
    print(" " * (n - 1 - i) + "*" * (i + 1))
# Out:
#          *
#         **
#        ***
#       ****
#      *****
#     ******
#    *******
#   ********
#  *********
# **********

# %%
n = 10

for i in range(n):
    print(" " * (n - 1 - i) + "*" * (2*i + 1))
# Out:
#          *
#         ***
#        *****
#       *******
#      *********
#     ***********
#    *************
#   ***************
#  *****************
# *******************

# %%
n = 10
width = 10 + 1

print("* " * width)

for i in range(n-2):
    print("*" + " "*(n-i-1) + "*"*(2*i+1) + " "*(n-i-1) + "*")

print("* " * width)
# Out:
# * * * * * * * * * * *
# *         *         *
# *        ***        *
# *       *****       *
# *      *******      *
# *     *********     *
# *    ***********    *
# *   *************   *
# *  ***************  *
# * * * * * * * * * * *

# %%
n = 10

for i in range(n):
    print(" " * (n-i-1), end="")

    if i == 0:
        print("*")
    elif i == n-1:
        print("* " * (n))
    else:
        print("*" + " "*(2*i-1) + "*")
# Out:
#          *
#         * *
#        *   *
#       *     *
#      *       *
#     *         *
#    *           *
#   *             *
#  *               *
# * * * * * * * * * *

# %%
n = 10

for i in range(n):
    print(" " * i, end="")

    if i == 0:
        print("* " * n)
    elif i == n-1:
        print("*")
    else:
        print("*" + " "*(2*(n-i)-3) + "*")
# Out:
# * * * * * * * * * *
#  *               *
#   *             *
#    *           *
#     *         *
#      *       *
#       *     *
#        *   *
#         * *
#          *

# %%
n = 10

for i in range(n):
    print(" " * (n-i-1), end="")

    if i == 0:
        print("*")
    elif i == n-1:
        print("* " * (n))
    else:
        print("*" + " "*(2*i-1) + "*")
for i in range(n):
    print(" " * i, end="")

    if i == n-1:
        print("*")
    else:
        print("*" + " "*(2*(n-i)-3) + "*")
# Out:
#          *
#         * *
#        *   *
#       *     *
#      *       *
#     *         *
#    *           *
#   *             *
#  *               *
# * * * * * * * * * *
# *                 *
#  *               *
#   *             *
#    *           *
#     *         *
#      *       *
#       *     *
#        *   *
#         * *
#          *

# %%
n = 9

for i in range(n):
    for j in range(n):

        if i == 0 or i == n-1 or j == 0 or j == n-1 or i == j or i + j == n-1:
            print("*", end=" ")
        else:
            print(" ", end=" ")

    print()
# Out:
# * * * * * * * * *
# * *           * *
# *   *       *   *
# *     *   *     *
# *       *       *
# *     *   *     *
# *   *       *   *
# * *           * *
# * * * * * * * * *

# %%
n = 9

for i in range(n):
    for j in range(n):

        if  i == j or i + j == n-1:
            print("*", end=" ")
        else:
            print(" ", end=" ")

    print()
# Out:
# *               *
#   *           *
#     *       *
#       *   *
#         *
#       *   *
#     *       *
#   *           *
# *               *
